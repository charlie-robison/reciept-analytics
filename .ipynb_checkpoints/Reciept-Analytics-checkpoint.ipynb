# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (0.0.324)
# Requirement already satisfied: requests<3,>=2 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.28.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.39)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.0.52)
# Requirement already satisfied: numpy<2,>=1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.21.5)
# Requirement already satisfied: pydantic<3,>=1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.4.2)
# Requirement already satisfied: anyio<4.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.5.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.6.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from langchain) (3.8.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: idna>=2.8 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.9.24)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: packaging>=17.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/charlierobison/opt/anaconda3/lib/python3.9/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (3.0.9)

# %%
from langchain.prompts import PromptTemplate # For Building Prompt.
from langchain.chat_models import ChatOpenAI # LLM.

# %%
prompt_str = """What is the most populated city in the state of Hawaii? Provide city name and no additional information.
"""

# %%
prompt = """
Can you please convert this unstructured receipt text data into a structured JSON object.
Here is the Unstructured Receipt Text Data:




Examples:

Example 1:
Unstructured Receipt Text Data:
Marley's Shop
123 Long Rd
Kailua, HI 67530
(808) 555-1234
CASHIER: JOHN
REGISTER #: 6
04/12/2023 6:30pm
Transaction ID: 5769009
PRICE   QTY  TOTAL
APPLES (1 lb)
2.99 2 5.98  1001
-1.00  999
Choco Dream Cookies
7.59 1 7.59   1001
SUBTOTAL
13.57
SALES TAX 8.5%
1.15
TOTAL
-14.72
VISA CARD            14.72
CARD#: ************1234
REFERENCE#: 6789
THANK YOU FOR SHOPPING WITH US!

Structured JSON Object:
{
  "ReceiptInfo": {
    "merchant": "Marley's Shop",
    "address": "123 Long Rd",
    "city": "Kailua",
    "state": "HI",
    "phoneNumber": "(808) 555-1234",
    "tax": "1.15",
    "total": "14.72",
    "receiptDate": "04/12/2023",
    "receiptTime": "6:30pm",


    "ITEMS": [
      {
        "description": "APPLES (1 lb)",
        "quantity": "2",
        "unitPrice": "2.99",
        "totalPrice": "5.98",
        "discountAmount": "-1.00"
      },
      {
        "description": "Choco Dream Cookies",
        "quantity": "1",
        "unitPrice": "7.59",
        "totalPrice": "7.59",
        "discountAmount": "0.00"
      },
    ]
  }
}

Example 2:
203
BUY ONE GET ONE FREE QUARTER POUNDER
W/CHEESE OR EGG MCMUFFIN
Go to www.mcdvoice.com within 7 days
and tell <UNKNOWN> about your visit.
Validation Code:
Expires 30 days after receipt date.
Valid at participating US
Survey Code:
<UNKNOWN>
McDonald's Restaurant <UNKNOWN>
2915 E MANCA RD
<UNKNOWN> 96822
TEL# <UNKNOWN>
Thank You Valued Customer
KS# 2
08/19/2023 03:33 PM
<UNKNOWN>
Order 03
1 Happy Meal Ch Burger
5.89
1 Cheeseburger
ONLY Onions
ONLY Ketchup
1 Extra Kids Fry
1 Apple Juice
1 NERF
Subtotal
5.89
Tax
0.28
Take-Out Total
6.17
Cashless
6.17
Change
0.00
MER# 467782
CARD ISSUER
ACCOUNT
Visa SALE
<UNKNOWN> <UNKNOWN> 130
TRANSACTION AMOUNT
6.17
CONTACTLESS
AUTHORIZATION CODE - <UNKNOWN>
SEQ# 107204
AID: A0000000031010
McDonald's Restaurant
Sign up for MyMcDonald's rewards
to earn points on future visit

Structured JSON Object:
{
  "ReceiptInfo": {
    "merchant": "McDonald's Restaurant",
    "address": "2915 E MANOA RD",
    "city": "Honolulu",
    "state": "HI",
    "phoneNumber": "(808) 555-1234",
    "tax": "0.28",
    "total": "6.17",
    "receiptDate": "08/19/2023",
    "receiptTime": "03:33 PM",


    "ITEMS": [
      {
        "description": "1 Happy Meal Ch Burger",
        "quantity": "1",
        "unitPrice": "5.89",
        "totalPrice": "5.89",
        "discountAmount": "0.00"
      },
    ]
  }
}





"""
