# %%
# !pip install faiss-cpu
# !pip install sentence-transformers

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.embeddings import HuggingFaceEmbeddings
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from nervaluate import Evaluator
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import os
import faiss
# Out:
# 2023-12-11 21:34:13 faiss.loader INFO: Loading faiss.
# 2023-12-11 21:34:13 faiss.loader INFO: Successfully loaded faiss.

# %%
categories = ["Grocery and Supermarkets", "Restaurants and Food Services", "Clothing and Apparel", 
              "Health and Beauty", "Electronics and Appliances", "Home and Garden", "Entertainment and Leisure"]

def get_training_data():
    folder_path = 'training_data/'
    category_train_test_data = {}
    category_training_items = []
    
    # List all files in the folder
    files = os.listdir(folder_path)
    i = 0

    # Gets the items for each category.
    for category in categories:
        # Gets the file identifier for the category.
        category_id = (category.split(" ")[0]).lower()
        file_name = f'{category_id}_items.txt'
        file_path = os.path.join(folder_path, file_name)
    
        # Check if it's a text file.
        if file_name.endswith('.txt'):
            with open(file_path, 'r') as file:
                # Read the content and split into list by newline character.
                text_content = file.read().split('\n')

                for item in text_content:
                    if 'items' in category_train_test_data:
                        # Adds the items to the category in the dict.
                        category_train_test_data['items'].append(item)
                    else:
                        category_train_test_data['items'] = []
                        category_train_test_data['items'].append(item)

                    if 'category' in category_train_test_data:
                        category_train_test_data['category'].append(category)
                    else:
                        category_train_test_data['category'] = []
                        category_train_test_data['category'].append(category)
                i += 1
    return category_train_test_data

category_data = pd.DataFrame(get_training_data())
category_data
# Out:
#                                                   items  \
# 0                                                  Milk
# 1                                                 Bread
# 2                                                  Eggs
# 3                                               Bananas
# 4                                       Chicken breasts
# ...                                                 ...
# 2622  Cinema Membership Exclusive Event Invitation R...
# 2623  Paint and Sip Canvas Easel Setup Instructions ...
# 2624  Musical Instrument Tuning Fork Calibration Gui...
# 2625  Popcorn Kernel Seasoning Recipe Book Ingredien...
# 2626  Theater Program Autograph Frame Maintenance Ti...
#
#                        category
# 0      Grocery and Supermarkets
# 1      Grocery and Supermarkets
# 2      Grocery and Supermarkets
# 3      Grocery and Supermarkets
# 4      Grocery and Supermarkets
# ...                         ...
# 2622  Entertainment and Leisure
# 2623  Entertainment and Leisure
# 2624  Entertainment and Leisure
# 2625  Entertainment and Leisure
# 2626  Entertainment and Leisure
#
# [2627 rows x 2 columns]

# %%
# Randomly shuffles the rows.
shuffled_data = category_data.sample(frac=1)

total_rows = shuffled_data.shape[0]
train_size = int(total_rows*0.8)
 
# Split data into test and train
train = shuffled_data[0:train_size]
test = shuffled_data[train_size:]

train
# Out:
#                                                  items  \
# 1481                                   Aloe vera plant
# 1215                                    Crochet shorts
# 1468                                         Hair mask
# 1865                                   Lawn Dethatcher
# 959                                    Knee-high socks
# ...                                                ...
# 1896                             Garden Hose Extension
# 2430                     Streaming Service Merchandise
# 342                                        Stop & Shop
# 851                                         Sweatshirt
# 2057  Garden Hose Quick Connect with Hose Valve Nozzle
#
#                        category
# 1481          Health and Beauty
# 1215       Clothing and Apparel
# 1468          Health and Beauty
# 1865            Home and Garden
# 959        Clothing and Apparel
# ...                         ...
# 1896            Home and Garden
# 2430  Entertainment and Leisure
# 342    Grocery and Supermarkets
# 851        Clothing and Apparel
# 2057            Home and Garden
#
# [2101 rows x 2 columns]

# %%
from sentence_transformers import SentenceTransformer
train_items = list(train['items'])
model = SentenceTransformer('bert-base-nli-mean-tokens')
train_vectors = model.encode(train_items)
train_vectors
# Out:
# 2023-12-11 21:34:40 sentence_transformers.SentenceTransformer INFO: Load pretrained SentenceTransformer: bert-base-nli-mean-tokens
# 2023-12-11 21:34:41 sentence_transformers.SentenceTransformer INFO: Use pytorch device: cpu
# ['Aloe vera plant',
#  'Crochet shorts',
#  'Hair mask',
#  'Lawn Dethatcher',
#  'Knee-high socks',
#  'Tie-dye loungewear set',
#  'Digital Art Print',
#  'Garden Hose Quick Connect with Hose Valve Flow',
#  'Ascot tie',
#  'Mango Habanero Wings',
#  'Rice Cooker',
#  'Oxfords',
#  'Cranberry Orange Scone',
#  'Satchel',
#  'Tie-dye sweatshirt',
#  'BPA-free water filter pitcher',
#  'Food Lion',
#  'Mango Avocado Salsa',
#  'Sweatpants',
#  'Crab Cakes',
#  'Mint Chocolate Chip Cupcakes',
#  'Garden Hose Coupler',
#  'Garden Trowel',
#  'Crossword Puzzle Book',
#  'Turkey Burger',
#  'Webcam',
#  'Diapers',
#  'Makeup artist services',
#  'Theater Program Quote',
#  'Iced Tea',
#  'Hand sanitizer',
#  'Acupressure mat',
#  'Smart Luggage',
#  'Razors',
#  'Laundry detergent',
#  "Bashas'",
#  'Fedora',
#  'Smart Desk Fan',
#  'Fitness Tracker',
#  'Deodorant',
#  'Camera Lens',
#  'Market Basket',
#  'Canned black beans',
#  'Indoor Rock Climbing Rope Safety Guidelines Emergency Contact Information Safety Measures',
#  'Garden Hose Quick Connect with Hose Valve Locking',
#  'USB Hub',
#  'Garden Hose Nozzle',
#  'Raspberry Dark Chocolate Tart',
#  'Novelty Sunglasses Repair Manual Warranty Terms and Conditions',
#  'Aldi',
#  'Craft Beer Flight Glassware Cleaning Instructions Safety Guidelines',
#  'Caramelized Onion and Gruyere Tart',
#  'Ruffled tank top',
#  'Ankle strap heels',
#  'Virtual Concert Setlist Poster Frame Hanging Instructions',
#  'Windbreaker pants',
#  'Garden Hose Kit',
#  'Chocolate Raspberry Tart',
#  'Power Strip',
#  'Pineapple Fried Rice',
#  'Cottage cheese',
#  'Smart TV',
#  'Garden Hose Quick Connect with Hose Valve Control',
#  'Eco-friendly menstrual cup',
#  'Raisins',
#  'Wireless Charging Desk Pad',
#  'Guitar Lessons Gift Certificate',
#  'Smart Spice Rack',
#  'Virtual Yoga Class Pass',
#  'Oranges',
#  'Faux fur vest',
#  'Cooking Class Voucher',
#  'Steak Fajitas',
#  'Tooth whitening kit',
#  'Energy drinks',
#  'Faux fur stole',
#  'Peach Iced Tea',
#  'Shredded lettuce',
#  'Puffer jacket',
#  'Tie-dye loungewear set',
#  'Golf Ball Marker Hat Clip Adapter Compatibility List Golf Accessories Compatibility Clip Attachment Tips',
#  'Hair spray',
#  'Garden Hose Quick Connect with Plastic Male',
#  'Maple syrup',
#  'Leave-in conditioner',
#  'Bamboo bedding',
#  'Zero-waste razor blades',
#  'Refillable notebook',
#  'Sequin blazer and shorts set',
#  'Garlic',
#  'Hair extensions',
#  'Espadrilles',
#  'Green Bean Almondine',
#  'Polo sweatpants',
#  'Body wash',
#  'Eyeliner',
#  'Garden Hose Quick Connect with Hose Valve Lever',
#  'Garden Hose Quick Connect with 1/2 Inch Thread',
#  'Biodegradable dental floss',
#  'Tie-dye shorts',
#  'Garden Hose Quick Connect with Hose Valve Release',
#  'Swimsuit',
#  'Garden Tool Sharpener',
#  'Biker jacket',
#  'Canned kidney beans',
#  'Table Tennis Ball',
#  'Jalapeño Popper Burger',
#  'Tunic dress',
#  'Mint Chocolate Chip Pancakes',
#  'Menstrual cup cleaner',
#  'Dried pineapple',
#  'Garden Hose Quick Connect with Hose Adapter',
#  'Cashews',
#  'Pregnancy tests',
#  'Bagels',
#  'Dried mango',
#  'Tights',
#  'Noise-Canceling Headphones',
#  'Chinos',
#  'Fajitas',
#  'Red Velvet Cake',
#  '',
#  'Rice',
#  'Frozen pie crust',
#  'Earrings',
#  'Golf Ball Marker Hat Clip Adapter Compatibility List Golf Accessories Compatibility',
#  'Pruning Shears',
#  'Cropped tank top',
#  'Garden Hose Quick Connect with Hose Valve Twist',
#  'Magic Wand',
#  'Comic Book Storage Box Liner Cleaning Tips Storage Conditions',
#  'Fringe skirt set',
#  'Eye cream',
#  'Smart Toothpaste Dispenser',
#  'Costco',
#  'Cucumber Mint Lemonade',
#  'Rock Band Instrument Set',
#  'Mint Mojito',
#  'Fence Panels',
#  'Smart Coffee Maker',
#  'Striped jumpsuit set',
#  'Chocolate Raspberry Cupcakes',
#  'Sweater shorts',
#  'Garden Hose Quick Connect with Hose Valve Open',
#  'Rosemary',
#  'Microblading',
#  'Skater dress',
#  'Ice Cream Sundae',
#  'Mojito',
#  'External Hard Drive',
#  'Photo Album',
#  'Digital Notepad',
#  'Stater Bros. Markets',
#  'Garden Hose Quick Connect with Hose Valve Spigot',
#  'Skater skirt',
#  'Red wine vinegar',
#  'Mesh top',
#  'Essential oils',
#  'Ruffle sleeve blouse',
#  'Frozen peas',
#  'Bamboo dish brush',
#  'Sandwich bags',
#  'Salsa verde',
#  'Shampoo',
#  'Halter maxi dress set',
#  'Pleated skirt set',
#  'Peach Bourbon Glazed Salmon',
#  'Castor oil',
#  'Beaded necklace',
#  'Chess Set',
#  'Refillable hand soap dispenser',
#  'Digital Movie Download Troubleshooting Guide',
#  'Dungarees',
#  'Corduroy skirt',
#  'Cheesecake',
#  'Sunglasses',
#  'Velvet jumpsuit',
#  'Garden Hose Quick Connect with Hose Valve Control',
#  'Instant noodles',
#  'Silicone-free hair products',
#  'Diffuser',
#  'Jazz Brunch Specials Menu Dietary Restrictions Disclaimer Dietary Options Specials Information',
#  'Coq au Vin',
#  'Fringe earrings',
#  'Smart Mirror with Lights',
#  'Weed Killer',
#  'Hair color treatment',
#  'Giant Food',
#  'Paint and Sip Canvas Easel',
#  'Lace-up tank top and skirt set',
#  'Bell sleeve top',
#  'Eyeshadow',
#  'Pasta Carbonara',
#  'Sparkling water',
#  'Batteries',
#  'Shaving cream',
#  'Garden Hose Quick Connect with Hose Valve Connector',
#  'Garden Hose Quick Connect with Hose Valve Plug',
#  'Raspberry Almond Croissant',
#  'Chocolate Banana Bread',
#  'Hormone-free birth control options',
#  'Mango Coconut Chia Pudding',
#  'T-shirt',
#  'Publix',
#  'Mini Basketball Hoop',
#  'Beef and Broccoli',
#  'Underwear',
#  'Overalls',
#  'Role-Playing Game Character Miniatures Painting Guide Color Palette Painting Tips',
#  'Buffalo Cauliflower Bites',
#  'Worcestershire sauce',
#  'Garden Hose Quick Connect with Hose Valve',
#  'Floral romper set',
#  'Model Building Kit',
#  'Calamari',
#  'Mineral sunscreen',
#  'Milkshake',
#  'Bourbon Glazed Salmon',
#  'Eggplant Parmesan',
#  'Chocolate Hazelnut Torte',
#  'Choker necklace',
#  'Garden Seat Cushions',
#  'Tripod',
#  'Tie-front top',
#  'Soy sauce',
#  'Eyebrow shaping',
#  'Cranberry Walnut Oatmeal',
#  'Blueberry Lemon Pound Cake',
#  'Trivia Night Host Kit',
#  'Toner',
#  "Collectors' Edition Blu-ray",
#  'Honeydew melon',
#  'Aromatherapy workshop',
#  'Oregano',
#  'Cargo jogger pants',
#  'Polo dress set',
#  'Garden Hose Quick Connect with Rubber Washer',
#  'Outdoor String Lights',
#  'Outdoor Umbrella',
#  'Garden Hose Quick Connect with Hose Valve Nozzle',
#  'Gua sha tool',
#  "Jazz Brunch Chef's Hat",
#  'Raspberry Almond Croissant',
#  'Smart Wall Outlet',
#  'Fried Pickles',
#  'Nintendo Switch',
#  'Tweezers',
#  'Apple Cinnamon Crepes',
#  'Cardigan',
#  'Garden Hose Swivel',
#  'Virtual Art Exhibition Pass',
#  'Air Conditioner',
#  'Mushroom Risotto',
#  'Sarong',
#  'Fried Green Tomatoes',
#  'Canned chickpeas',
#  'Ripped denim skirt',
#  'Mango Chipotle BBQ Ribs',
#  'Novelty Sunglasses Repair Kit',
#  'Trench coat',
#  'Off-the-shoulder sweater dress',
#  'Fascinator',
#  'Smart Coffee Mug',
#  'Relaxation music',
#  'Chicken Gyro',
#  'Peking Duck',
#  'Magazine Subscription Gift Wrapping Service',
#  'Leather jacket set',
#  'Track pants',
#  'Cherry Almond Tart',
#  'Peach Cobbler',
#  'Dental floss picks',
#  'Layered necklace',
#  'Smart TV Power Cable',
#  'Fitness Tracker',
#  'Infrared sauna session',
#  'Garden Hose Quick Connect with Hose Valve Knob',
#  'Raised Garden Bed',
#  'Suspenders',
#  'Garden Hose Quick Connect with Hose Valve Flow',
#  'Ribbed tank top',
#  'Non-toxic nail polish',
#  'Laser Tag Session',
#  'Hot water bottle',
#  'Garden Hose',
#  'Pancakes',
#  'Sesame Ginger Tofu',
#  'Bleach',
#  'Blue cheese dressing',
#  'Canned pears',
#  'Grass Seed',
#  'Rain boots',
#  'Dance Dance Revolution Mat',
#  'Blueberry Lemon Ricotta Pancakes',
#  'Mango Raspberry Smoothie',
#  'Hair accessories',
#  'Chicken Fried Rice',
#  'Cookbook',
#  'Trivia Night Entry',
#  'Gaming Mouse',
#  'Roasted Red Pepper Hummus',
#  'Antiseptic ointment',
#  'Garden Hose Quick Connect with Hose Valve Rotate',
#  'Smart Mirror with Makeup Lights',
#  'Magazine Subscription',
#  'Smart TV',
#  'Outdoor Plant Stand',
#  'Garden Hose Quick Connect with Hose Valve Adapter',
#  'Curling iron',
#  'Yoga mat cleaner',
#  'Maple Glazed Bacon',
#  'Paperbag waist shorts',
#  'Tuxedo',
#  'Raspberry Swirl Cheesecake',
#  'Cotton balls',
#  "Collectors' Card Trading Post Directory Map",
#  'Garden Hose Quick Connect with 5/8 Inch Thread',
#  'Salsa verde',
#  'Live Comedy Special Download',
#  'Smart Trash Bin',
#  'Coconut oil',
#  'Eco-friendly yoga mat',
#  'Sweet Potato Fries',
#  'Car Dash Cam',
#  'Popcorn kernels',
#  'Eco-friendly pens',
#  'Massage Chair',
#  'Plant-based protein bars',
#  'Massage oil',
#  'Movie Soundtrack Sheet Music',
#  'Quinoa',
#  'Chocolate Raspberry Cupcakes',
#  'Crop tank top',
#  'Magazine Holder',
#  'Plaid mini skirt',
#  'Cereal',
#  'Garden Hose Quick Connect with Hose Valve Twist',
#  'Karaoke Songbook',
#  'Garden Hose Quick Connect with Hose Barb',
#  'Musical Instrument Case',
#  'Key Lime Pie',
#  'Chicken Quesadilla',
#  'Mint Chocolate Chip Ice Cream',
#  'Sweet Potato Gnocchi',
#  'Smart TV Screen Cleaner',
#  'Garden Hose Quick Connect with Hose Valve Ball',
#  'Wrap blouse',
#  'Lace-up tank top and skirt set',
#  'Bar soap',
#  'Tie clip',
#  'Game of Thrones Board Game',
#  'Smart Backpack',
#  'Movie Soundtrack Vinyl Cleaner',
#  'Facial roller',
#  'Outdoor Movie Screen Stand Bag',
#  'Tissues',
#  'Rain Barrel',
#  'Garden Arbor',
#  "Collectors' Card Binder",
#  'Wide-leg jumpsuit',
#  'Frozen taquitos',
#  'Outdoor Movie Screen Bag',
#  'Garden Hose Quick Connect 3/4 Inch',
#  'Indoor Rock Climbing Rope Safety Guidelines Emergency Contact Information',
#  'Smart Refrigerator',
#  'Pumpkin Spice Waffles',
#  'Paint and Sip Canvas Easel Setup Instructions Tips and Tricks',
#  'Garden Hose Quick Connect with Hose Valve Handle',
#  'Tie-dye pullover and joggers set',
#  'Garlic Parmesan Wings',
#  'Tie-dye wrap dress',
#  'Smart Weight Scale',
#  'Salmon fillets',
#  'Sesame Chicken',
#  'Garden Hose Connector',
#  'Wrap skirt',
#  'Sunscreen',
#  'Movie Soundtrack Vinyl',
#  'Climbing Gear Rental',
#  'Cajun Shrimp Pasta',
#  'Garden Hose Quick Connect with Easy Connect',
#  'Role-Playing Game Character Miniatures Painting Guide Color Palette Painting Tips Miniature Care',
#  'Nail clippers',
#  'Outdoor Movie Screen Stand',
#  'Drone',
#  'Garden Hose Quick Connect with Water Flow Control',
#  'Giant Eagle',
#  'Taco seasoning',
#  'Hawaiian Pizza',
#  'Dress',
#  'Sweet and Sour Chicken',
#  'Virtual Concert Encore',
#  'Mint Chocolate Chip Truffles',
#  'Sleep mask',
#  'Baking soda',
#  'Streaming Device Batteries Installation Guide Safety Precautions Battery Replacement Guidelines',
#  'Garden Hose Replacement',
#  'Photo Album Scrapbook',
#  'Chocolate Fondue',
#  'Dental floss',
#  'Corduroy pants',
#  'Coconut Lime Pie',
#  'Hairspray',
#  'Garden Hose Quick Connect with Hose Valve Lock',
#  'Potted Plants',
#  'Lawn Aerator',
#  'Wireless Mouse Pad',
#  'Protein bars',
#  'Embroidered jeans',
#  'Sequin dress set',
#  'Wrap cardigan',
#  'Cranberry Orange Cheesecake',
#  'Mint Chocolate Chip Cookies',
#  'Beanie',
#  'Candles',
#  'Toaster',
#  'Photo Booth Prints',
#  'Water filter',
#  'High-low skirt',
#  'Hair Dryer',
#  'Baby wipes',
#  'Popcorn Maker',
#  'Silk pillowcase',
#  'Pain relievers',
#  'Tote bag',
#  'Chicken Pot Pie',
#  'Cookies',
#  'Buffalo Chicken Flatbread',
#  'Garden Hose Quick Connect with Stop Valve',
#  'Peplum top',
#  'Seltzer water',
#  'Allergy medication',
#  'Garden Sickle',
#  'Paint and Sip Canvas Holder',
#  'Microwave',
#  'Table Tennis Table Cover',
#  'Garden Hose Quick Connect with Hose Valve Pipe',
#  'Nail polish',
#  'Garden Hose Quick Connect with Hose Valve Switch',
#  'Mayonnaise',
#  'Garden Hose Quick Connect with Hose Valve Coupler',
#  'Pasta Primavera',
#  'Cargo vest',
#  'Chocolate Raspberry Mousse',
#  'Socks',
#  'Digital Thermometer',
#  'Highlighter',
#  'Digital Tape Measure',
#  'Balsamic Glazed Brussels Sprouts',
#  'Fringed boots',
#  'Cranberry Orange Pound Cake',
#  'Coconut Lime Pie',
#  'Garden Hose Quick Connect with Hose Valve Fitting',
#  'False eyelashes',
#  'DIY natural cleaning recipes book',
#  'Parmesan cheese',
#  'Aromatherapy candles',
#  'Marshmallows',
#  'Outdoor Movie Screen Repair Kit Instructions Safety Guidelines',
#  'Smart Fridge Magnet',
#  'G-string',
#  'Tassel sandals',
#  'Miniature Golf Ball',
#  'Watering Can',
#  'Digital Voice Recorder',
#  'Sweet Potato Waffles',
#  'Cranberry Orange Cheesecake',
#  'Ankle boots',
#  'Silk cami',
#  'Fishnet stockings',
#  'Garden Hose Quick Connect with Hose Valve Pipe',
#  'Dried apricots',
#  'Pumpkin Spice Oatmeal',
#  'Leather gloves',
#  'Garden Hose Quick Connect with Hose Valve Tap',
#  'Garden Hose Quick Connect Water Stop',
#  'Glass food storage containers',
#  'Blueberry Lemon Muffins',
#  'Garden Hose Quick Connect with Hose Valve Connector',
#  'Garden Hose Nut',
#  'Baby spinach',
#  'Sweater',
#  'Fitness Class Membership',
#  'Ruched dress',
#  'Action Figure Trading Card',
#  'Waxing services',
#  'Pumpkin Spice Pancakes',
#  'Athletic shorts',
#  "Collectors' Card Album",
#  'Hot dogs',
#  'Cropped hoodie',
#  'Theater Program Autograph',
#  'Barbecue sauce',
#  'Off-the-shoulder top',
#  'Personal training session',
#  'Virtual Concert Backstage Pass',
#  'Garden Hose Quick Connect with Gasket',
#  'Garden Hose Quick Connect Female',
#  'Strawberry Shortcake',
#  'Mango Coconut Rice Pudding',
#  'Paint and Sip Canvas Easel Setup Instructions',
#  'Ground cayenne pepper',
#  'Movie Rental Subscription',
#  'Sequin mini dress',
#  'Mulch',
#  'Racerback tank',
#  'Buffalo Cauliflower Pizza',
#  'Off-the-shoulder dress set',
#  'Garden Hose Timer',
#  'Caprese Panini',
#  'Canned chickpeas',
#  'Novelty Sunglasses Repair Manual',
#  'Outdoor Wall Decor',
#  'Garden Hose Quick Connect with Hose Valve Coupler',
#  'Lawn Fertilizer',
#  'Craft Beer Flight Glassware',
#  'Smart Plant Pot',
#  'Harris Teeter',
#  'Cranberry Walnut Salad',
#  'Limes',
#  'Garden Hose Quick Connect with Hose Valve Release',
#  'Outdoor Movie Projector',
#  'Cajun Chicken Caesar Salad',
#  'Halter maxi dress',
#  'Cold-shoulder sweater',
#  'Leather jacket set',
#  'Velvet pants set',
#  'Chicken and Mushroom Risotto',
#  'Tie-dye loungewear set',
#  'Wool socks',
#  'All-purpose cleaner',
#  'Strappy sandals',
#  'Zero-waste shopping bags',
#  'Sequin skirt',
#  'Blueberry Cheesecake Ice Cream',
#  'Virtual Concert Setlist',
#  'Interactive Movie App',
#  'Ground cloves',
#  'Bacon Cheeseburger',
#  'Pumpkin Spice Latte Truffles',
#  'Ratatouille',
#  'Chocolate Raspberry Truffle',
#  'Pool Table Maintenance Kit',
#  'Peasant top',
#  'Polo hat',
#  'Leg warmers',
#  'Off-the-shoulder blouse',
#  'Magic the Gathering Cards',
#  'Garden Row Cover',
#  'Blueberry Cheesecake Ice Cream',
#  'Raspberry Dark Chocolate Tart',
#  'Garden Hose Quick Connect with Threaded Fitting',
#  'Camo jacket and pants set',
#  'Mango Avocado Salad',
#  'Digital Movie Download Troubleshooting Hotline Hours of Operation Support Availability',
#  'Movie Night In Gift Basket',
#  'Sustainable period products',
#  'Fertilizer',
#  'Cashew milk',
#  'Bomber cardigan',
#  'Hot Wings',
#  'Garden Hose Quick Connect with Hose Union',
#  'Blender',
#  'Mesh cover-up set',
#  'Incense sticks',
#  'Smart Wake-Up Light',
#  'Banana Split',
#  'Cheddar Biscuits',
#  'H-E-B',
#  'Theater Program Autograph Frame Maintenance Tips Cleaning Recommendations Frame Care',
#  'Essential oil rollerball',
#  'Cantaloupe',
#  'Chicken Alfredo Pizza',
#  'Garden Hose Mender',
#  'Jazz Brunch Menu',
#  'Garden Hose Quick Connect with Hose Valve Coupler',
#  'Garden Hose Quick Connect with Hose Valve Stop',
#  'Sweet Potato Fries',
#  'Garden Hose Quick Connect Stainless Steel',
#  'Garden Rake',
#  'Garden Hose Wand',
#  'Deck Stain',
#  'Necklace',
#  'Feminine hygiene products',
#  'Mascara',
#  'Sneakers',
#  'Cookies',
#  'Bodysuit',
#  'Chicken Piccata',
#  'Raspberry Chipotle Glazed Ribs',
#  'Board Game Cafe Gift Card',
#  'Garden Hose Quick Connect with Hose Valve Coupler',
#  'Mango Avocado Salsa',
#  'Pleather jacket',
#  'Juice',
#  'Popcorn Kernel Popper',
#  'Bamboo charcoal toothbrush',
#  'Flip-flops',
#  'Polo dress set',
#  'Sweet Potato Pancakes',
#  'Mints',
#  'Ice cream',
#  'Jazz Album Vinyl',
#  'Garden Cart Wheels',
#  'Music Festival Merchandise Coupon',
#  'Feminine hygiene products',
#  'Tie-dye kimono',
#  'Chocolate Hazelnut Torte',
#  'Jazz Brunch Specials Menu Dietary Restrictions Disclaimer Dietary Options',
#  'Sweatband',
#  'Wallet',
#  'Sweet and sour sauce',
#  'Mango Coconut Rice Pudding',
#  'Garden Scissors',
#  'Frozen appetizers',
#  'Polo dress',
#  'Makeup brushes',
#  'Cinnamon Roll',
#  'Music Festival VIP Pass Lanyard Usage Instructions Lanyard Attachment Tips',
#  'Pumpkin Spice Biscotti',
#  'Bird Feeder',
#  'Sequin dress',
#  'White vinegar',
#  'Cotton swabs',
#  'Spaghetti Bolognese',
#  'Smart Light Bulbs',
#  'Pumpkin Spice Latte Truffles',
#  'Hydrogen peroxide',
#  'Shrimp Alfredo',
#  'Vegetarian Sushi Rolls',
#  'Raspberry Almond Croissant',
#  'Chicken Caesar Wrap',
#  'Smart Glasses',
#  'Puzzle Mat',
#  'Rosehip oil',
#  'Streaming Device Batteries Installation Guide Safety Precautions',
#  'Butter',
#  'Smart Doorbell',
#  'Cinema Membership Exclusive Event Invitation RSVP Deadline RSVP Instructions',
#  'Polka dot pants',
#  'Smart Light Switch',
#  'Smart Shower Head',
#  'Coconut Lime Shrimp',
#  'Green tea',
#  'Baby spinach',
#  'Resistance bands',
#  'Gingerbread Cookies',
#  'Chocolate Mousse',
#  'Garden Hose Quick Connect with Hose Valve Lever',
#  'Role-Playing Game Character Miniatures Painting Guide',
#  'Vegetable Stir-Fry',
#  'Music Streaming Gift Card',
#  'Tuna',
#  'DIY Home Decor Kit',
#  'Cream cheese',
#  'Ginger Soy Glazed Salmon',
#  'Indoor Golf Simulator Session',
#  'Wireless Keyboard',
#  'Digital Drawing Tablet',
#  'Gluten-free vitamins',
#  'Table Tennis Racket',
#  'Pumpkin Spice Panna Cotta',
#  'Bomber jacket',
#  'Cloak',
#  'Garden Hose Quick Connect with Comfort Grip',
#  'Air Purifier',
#  'Chicken and Rice Soup',
#  'Garden Hose Quick Connect Repair Kit',
#  'Mango Coconut Rice',
#  'Adult Coloring Book',
#  'Garden Statues',
#  'Smart Trash Can',
#  'Nachos',
#  'Pumpkin Spice Oatmeal',
#  'Silk scarf',
#  'Ground beef',
#  'Garden Hose Quick Connect with Hose Valve Spigot',
#  'Sandals',
#  'Tortilla Soup',
#  'Polka dot crop top',
#  'Tie-dye hoodie and leggings set',
#  'Bow headwrap',
#  'Water flosser',
#  'Wireless Charging Stand',
#  'Coffee',
#  'Smart TV Dust Cover',
#  'Argan oil',
#  'Music Composition Software',
#  'Garden Hose Quick Connect with Hose Valve Twist',
#  'Lace-up ankle boots',
#  ' Flow',
#  'Smart Pet Feeder',
#  'Monokini',
#  'Fur stole',
#  'Frozen pie',
#  'Coconut milk',
#  'Beignets',
#  'Tuna Tartare',
#  'Flavored water',
#  'Chicken Parmesan Sandwich',
#  'Smart TV Wall Mount Installation Guide Safety Precautions Installation Tools',
#  'Peach Melba',
#  'Mango Coconut Smoothie',
#  'Fried Oreos',
#  'Popcorn Kernel Seasoning Sampler',
#  'Syrup',
#  'Mushrooms',
#  'Bucket bag',
#  'Floral maxi skirt',
#  'Sequin tank top',
#  'Snack Combo',
#  'Pleated skirt set',
#  "Magazine Collector's Case",
#  'Biodegradable trash bags',
#  'Fitted blazer',
#  'Cranberry Orange Sorbet',
#  'Chocolate Raspberry Mousse',
#  'Trail mix',
#  'Fitness class subscription',
#  'Lemon Pepper Chicken',
#  'Cufflinks',
#  'Olive oil',
#  'Garden Hose Quick Connect with Hose Valve Adapter',
#  'Movie-themed Puzzle',
#  'Apple Pie',
#  'Garden Hose Reel',
#  'Sweater dress',
#  'Gouda Mac and Cheese',
#  'Table Tennis Racket Grip Replacement Guide',
#  'Popcorn Kernel Seasoning Recipe Book Ingredients',
#  'Mesh cover-up',
#  'Tiramisu',
#  'Compression socks',
#  'Virtual Escape Room Challenge',
#  'Sweet Potato Fries',
#  'Sweater set',
#  'Popcorn Kernel Seasoning Refill',
#  'Baklava',
#  'Garden Hose Bib Cover',
#  'Candy',
#  'Streaming Device Batteries Installation Guide',
#  'Video Game Controller',
#  'Raspberry Swirl Brownies',
#  'Tweed skirt',
#  "Collectors' Card Sleeve",
#  'Garden Hose Quick Connect with Hose Valve Spigot',
#  'Avocado Lime Ranch Salad',
#  'Comic Book Storage Box Liner Cleaning Tips Storage Conditions Cleaning Recommendations',
#  'Blueberry Lemon Curd Tart',
#  'Brown Butter Sage Gnocchi',
#  'Garden Watering Wand',
#  'Frozen fruit',
#  'Blueberry Lemon Bars',
#  'Lemon Blueberry Pound Cake',
#  'Lace-up boots',
#  'Reusable cotton rounds',
#  'Pumpkin Spice Creme Brulee',
#  'Pom-pom beaded earrings',
#  'Puzzle Table',
#  'Ground ginger',
#  'Magazine Subscription Renewal Reminder',
#  'Smartwatch',
#  'Frozen seafood',
#  'Garden Twine',
#  'Cleansing wipes',
#  'Chiffon kimono',
#  'Supplements',
#  'Graphic tank top',
#  'Floss',
#  'Garden Hose Quick Connect Adapter',
#  'Pumpkin Ravioli',
#  'Virtual Cooking Class',
#  'French Fries',
#  'Chocolate Pecan Pie',
#  'Leggings',
#  'Bubble bath',
#  'Tunic top',
#  'Meijer',
#  'Chicken Shawarma',
#  'Collared dress',
#  'Buttermilk Biscuits',
#  'Vegan omega-3 supplements',
#  "Collectors' Card Trading Post Directory Map Location Key",
#  'Apron dress',
#  'Tortilla chips',
#  'Corset',
#  'Sunscreen',
#  'Garden Wagons',
#  'Heated Blanket',
#  'Hat',
#  'Margarita',
#  'Smart Food Storage Container',
#  'Garden Hose Quick Connect with Hose Valve Tap',
#  'Chocolate Covered Cherry Truffles',
#  'Mango Coconut Chia Pudding',
#  'Pumpkin Spice Biscotti',
#  'Dish scrubbers',
#  'ShopRite',
#  'Chicken Caesar Salad Wrap',
#  'Nail polish remover',
#  'Tabletop RPG Dice Set',
#  'Bamboo cutlery set',
#  'Natural deodorant',
#  'Rain Gauge',
#  'Hiking sandals',
#  'Photo Album Display Case Lock',
#  'Fitness tracker',
#  'Streaming Service Troubleshooting FAQ Index Hyperlinks',
#  'Hoverboard',
#  'Comic Book Storage Box Liner Cleaning Tips',
#  'Iron',
#  'Fajita seasoning',
#  'Garden Hose Quick Connect with Hose Valve Tube',
#  'Clam Chowder',
#  'Denim jumpsuit',
#  'Ketchup',
#  'Polo romper',
#  'Tie-dye hoodie and leggings set',
#  'Garden Hose Quick Connect with Hose Valve Shut Off',
#  'Cranberry Orange Pound Cake',
#  'Yoga Mat',
#  'Cruelty-free makeup',
#  'Garden Hose Quick Connect with Hose Valve Plug',
#  'Cinema Membership Rewards Program',
#  'Beaded sandals',
#  'Trail mix',
#  'Flour',
#  'Garden Hose Quick Connect with Hose Valve Spigot',
#  'Smart Door Lock',
#  'Turtleneck',
#  'Pom-pom sandals',
#  'Chocolate Peanut Butter Pie',
#  'Whole bean coffee',
#  'Pergola Kit',
#  'Pulled Beef Tacos',
#  'Sweat headband',
#  'Frayed denim shorts',
#  'Garden Hose Quick Connectors',
#  'Denim joggers',
#  'Pajamas',
#  'Movie Soundtrack Karaoke Microphone',
#  'Nail files',
#  'Garden Hose Quick Connect with Hose Valve Handle',
#  'Garden Hose Guard',
#  'Cold medicine',
#  'Garden Hose Quick Connect with Hose Valve Handle',
#  'Floral headband',
#  'Action Figure Poster',
#  'Hand lotion',
#  'Sculpture Workshop Admission',
#  'Cargo crop pants',
#  'Garden Hose Quick Disconnect',
#  'Musical Instrument Rental',
#  'Garden Hose Y Connector',
#  'Protein powder',
#  'Indoor Trampoline Park Pass',
#  'Messenger bag',
#  'Streaming Service Gift Card',
#  'Music Festival Ticket Stub',
#  'Pumice stone',
#  'Cranberry Orange Bread',
#  'Yoga mat',
#  'Kimono cardigan',
#  'Body lotion',
#  'Resistance bands',
#  'Silicone-free hair serum',
#  'Flatform sandals',
#  'Poncho',
#  'Duct tape',
#  'Cajun Shrimp and Grits',
#  'Weis Markets',
#  'Garden Edging Stones',
#  'Movie Night Subscription Box',
#  'Turkey Cranberry Panini',
#  'Smart Bike Lock',
#  'Makeup remover',
#  'Mango Smoothie',
#  'Cough syrup',
#  'Tie-dye tank top',
#  'Board Games',
#  'External SSD',
#  'Teriyaki Chicken Bowl',
#  'Magic Kit',
#  'Comic Book Display Rack',
#  'Water bottle',
#  'Smart Mattress',
#  'Movie Soundtrack Karaoke Microphone Troubleshooting Tips Troubleshooting Steps',
#  'Sweet Potato Waffles',
#  'Jigsaw Puzzle',
#  'Headband',
#  'Cajun Chicken Tacos',
#  ' Display Stand',
#  'Peplum dress',
#  'Garden Hose Leader',
#  'Smart Scale',
#  'Toilet paper',
#  'Cucumber Salad',
#  'Vegetable Curry',
#  'Theater Program Bookmark',
#  'Herbal tea',
#  'Watermelon',
#  'Onions',
#  'Adaptogenic herbs',
#  'Spinach and Feta Stuffed Chicken',
#  'Pulled Pork Nachos',
#  'Garden Hose Quick Connect with Hose Valve Twist',
#  'Chicken Tandoori',
#  'Apple juice',
#  'Sweater tunic set',
#  'Fringe top and skirt set',
#  'Smart & Final',
#  'Face masks',
#  'Canned black beans',
#  'Lace-up tank top',
#  'Margarita Pizza',
#  'Garden Hose Quick Connect with Dual Shut Off',
#  'Pumpkin Spice Cupcakes',
#  'Garden Hose Quick Connect with Hose Valve Lock',
#  'Craft Beer Flight Glasses',
#  'Garden Hose Quick Connect with Hose Valve Flow',
#  'Pumpkin Spice Latte',
#  'Recycled toilet paper',
#  'Cajun Crab Cakes',
#  'Indoor Rock Climbing Grips',
#  'Universal Remote Control',
#  'Mango Pineapple Salsa',
#  'Conditioner',
#  'Halter top',
#  'Virtual Concert Setlist Poster Frame Hanging Instructions Wall Material Compatibility Hanging Tips',
#  'Chili powder',
#  'Climbing Wall Day Pass',
#  'Dried bay leaves',
#  'Polo bodysuit',
#  'Jelly sandals',
#  'Chocolate Hazelnut Cheesecake',
#  'Olives',
#  'Garden Hose Bib',
#  'Table Tennis Net',
#  'Cutout shoulder top',
#  'Puzzle Mat Piece Missing Report Template Customer Information Form',
#  'Craft Beer Flight Menu',
#  'Multivitamins',
#  'Brooch',
#  'Bookshelf Speaker',
#  'Coloring Book',
#  'Custom Puzzle',
#  'Peanut Butter Chocolate Shake',
#  'Frozen waffles',
#  'Garden Hose Quick Connect with Hose Valve Adapter',
#  'Sequin blazer',
#  'Mint Chocolate Chip Brownies',
#  'Eco-friendly dish soap',
#  'Tomatoes',
#  'Floral kimono',
#  'Shoes',
#  'Smart Wine Dispenser',
#  'Garden Hose Quick Connect Fittings',
#  'DJ Equipment',
#  'Virtual Concert Livestream Pass',
#  'Organic cotton robe',
#  "Shrimp Po' Boy",
#  'Tomato Mozzarella Salad',
#  'Tie-dye hoodie dress',
#  'Sweat shorts',
#  'Lace-up booties',
#  'Ruffle hem top',
#  'Pumpkin Spice Biscotti',
#  'Zero-waste lunch containers',
#  'Musical Instrument Maintenance Kit',
#  'Caramelized Pear and Brie Crostini',
#  'Crew socks',
#  'Sour cream',
#  'Music Festival Merchandise',
#  'Orange Sorbet',
#  'Jacket',
#  'Electric Toothbrush',
#  'Garden Hose Quick Connect with Hose Valve Connector',
#  'Ralphs',
#  'Crochet dress',
#  'Compostable bath sponge',
#  'Soda',
#  'Dishwasher detergent',
#  'Beef Burrito',
#  'Granola bars',
#  'Concert Ticket Stub Holder',
#  'Soy sauce',
#  'Tofu Pad Thai',
#  'Allergy medication',
#  'BBQ Chicken Sandwich',
#  'Paint and Sip Canvas',
#  'Deck Tiles',
#  'Garden Hose Quick Connect with Water Stop',
#  'Hairbrush',
#  'Cherry Pie',
#  'Cilantro',
#  'Garden Hose Quick Connect with Hose Fitting',
#  'Garden Hose Adapter',
#  'Tie-dye tank top and shorts set',
#  'Chocolate Hazelnut Tart',
#  'Comedy Special DVD',
#  ...]

# %%
import faiss

vector_shape = train_vectors.shape[1]
index = faiss.IndexFlatL2(vector_shape)
faiss.normalize_L2(train_vectors)
index.add(train_vectors)

# %%
test_items = test['items'].to_numpy()
test_vectors = model.encode(test_items)
test_vectors

# %%
k = index.ntotal
distances, ann = index.search(_vector, k=k)
